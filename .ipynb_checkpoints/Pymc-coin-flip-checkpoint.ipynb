# %% [markdown]
# # Notebook 1 — The PyMC workflow, on the simplest model there is
#
# **What you will practise here:** the six steps you repeat in *every* PyMC job.
#
# 1. Make some fake data where you already know the right answer.
# 2. Write down the model.
# 3. Check your priors before you look at the data.
# 4. Run the sampler.
# 5. Check whether the sampler worked (this is the ArviZ part).
# 6. Check whether the model fits the data.
#
# **The example:** we flip a bent coin. We want to find `p`, the chance it lands heads.
# That is it. One unknown number. Everything you learn here carries over to models
# with 20 unknowns.
#
# **Words you will see (plain meanings):**
#
# - **Prior** - what you believe about a parameter *before* looking at the data.
# - **Posterior** - what you believe *after* looking at the data. This is the answer.
# - **Likelihood** - the part of the model that says how the data is generated from the parameters.
# - **Sampler / MCMC** - a program that draws thousands of plausible parameter values from the posterior.
#   You never get one number, you get a cloud of numbers.
# - **Draw** - one sample from that cloud.
# - **Chain** - one independent run of the sampler. We run several and check they agree.

# %%
# %pip install pymc
# %pip install arviz
# Out:
# Requirement already satisfied: pymc in c:\users\sents\anaconda3\lib\site-packages (6.3.2)
# Requirement already satisfied: arviz<2.0,>=1.1.0 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (1.3.0)
# Requirement already satisfied: cachetools<7,>=4.2.1 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (6.2.6)
# Requirement already satisfied: cloudpickle in c:\users\sents\anaconda3\lib\site-packages (from pymc) (3.0.0)
# Requirement already satisfied: numpy>=1.25.0 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (2.1.3)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (2.2.3)
# Requirement already satisfied: pytensor<3.4,>=3.2.2 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (3.3.1)
# Requirement already satisfied: rich>=13.7.1 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (13.9.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (1.15.3)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\sents\anaconda3\lib\site-packages (from pymc) (4.16.0)
# Requirement already satisfied: arviz_base<1.4.0,>=1.3.0 in c:\users\sents\anaconda3\lib\site-packages (from arviz<2.0,>=1.1.0->pymc) (1.3.0)
# Requirement already satisfied: arviz_stats<1.4.0,>=1.3.0 in c:\users\sents\anaconda3\lib\site-packages (from arviz_stats[xarray]<1.4.0,>=1.3.0->arviz<2.0,>=1.1.0->pymc) (1.3.2)
# Requirement already satisfied: arviz_plots<1.4.0,>=1.3.0 in c:\users\sents\anaconda3\lib\site-packages (from arviz<2.0,>=1.1.0->pymc) (1.3.1)
# Requirement already satisfied: xarray>=2024.11.0 in c:\users\sents\anaconda3\lib\site-packages (from arviz_base<1.4.0,>=1.3.0->arviz<2.0,>=1.1.0->pymc) (2025.4.0)
# Requirement already satisfied: lazy_loader>=0.4 in c:\users\sents\anaconda3\lib\site-packages (from arviz_base<1.4.0,>=1.3.0->arviz<2.0,>=1.1.0->pymc) (0.4)
# Requirement already satisfied: xarray-einstats in c:\users\sents\anaconda3\lib\site-packages (from arviz_stats[xarray]<1.4.0,>=1.3.0->arviz<2.0,>=1.1.0->pymc) (0.11.0)
# Requirement already satisfied: setuptools>=59.0.0 in c:\users\sents\anaconda3\lib\site-packages (from pytensor<3.4,>=3.2.2->pymc) (80.9.0)
# Requirement already satisfied: numba<=0.67.0,>=0.58 in c:\users\sents\anaconda3\lib\site-packages (from pytensor<3.4,>=3.2.2->pymc) (0.61.0)
# Requirement already satisfied: filelock>=3.15 in c:\users\sents\anaconda3\lib\site-packages (from pytensor<3.4,>=3.2.2->pymc) (3.17.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\sents\anaconda3\lib\site-packages (from numba<=0.67.0,>=0.58->pytensor<3.4,>=3.2.2->pymc) (0.44.0)
# Requirement already satisfied: packaging in c:\users\sents\anaconda3\lib\site-packages (from lazy_loader>=0.4->arviz_base<1.4.0,>=1.3.0->arviz<2.0,>=1.1.0->pymc) (26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sents\anaconda3\lib\site-packages (from pandas>=0.24.0->pymc) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sents\anaconda3\lib\site-packages (from pandas>=0.24.0->pymc) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sents\anaconda3\lib\site-packages (from pandas>=0.24.0->pymc) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sents\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->pymc) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sents\anaconda3\lib\site-packages (from rich>=13.7.1->pymc) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sents\anaconda3\lib\site-packages (from rich>=13.7.1->pymc) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sents\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: arviz in c:\users\sents\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: arviz_base<1.4.0,>=1.3.0 in c:\users\sents\anaconda3\lib\site-packages (from arviz) (1.3.0)
# Requirement already satisfied: arviz_stats<1.4.0,>=1.3.0 in c:\users\sents\anaconda3\lib\site-packages (from arviz_stats[xarray]<1.4.0,>=1.3.0->arviz) (1.3.2)
# Requirement already satisfied: arviz_plots<1.4.0,>=1.3.0 in c:\users\sents\anaconda3\lib\site-packages (from arviz) (1.3.1)
# Requirement already satisfied: numpy>=2 in c:\users\sents\anaconda3\lib\site-packages (from arviz_base<1.4.0,>=1.3.0->arviz) (2.1.3)
# Requirement already satisfied: xarray>=2024.11.0 in c:\users\sents\anaconda3\lib\site-packages (from arviz_base<1.4.0,>=1.3.0->arviz) (2025.4.0)
# Requirement already satisfied: typing-extensions>=3.10 in c:\users\sents\anaconda3\lib\site-packages (from arviz_base<1.4.0,>=1.3.0->arviz) (4.16.0)
# Requirement already satisfied: lazy_loader>=0.4 in c:\users\sents\anaconda3\lib\site-packages (from arviz_base<1.4.0,>=1.3.0->arviz) (0.4)
# Requirement already satisfied: scipy>=1.13 in c:\users\sents\anaconda3\lib\site-packages (from arviz_stats<1.4.0,>=1.3.0->arviz_stats[xarray]<1.4.0,>=1.3.0->arviz) (1.15.3)
# Requirement already satisfied: xarray-einstats in c:\users\sents\anaconda3\lib\site-packages (from arviz_stats[xarray]<1.4.0,>=1.3.0->arviz) (0.11.0)
# Requirement already satisfied: packaging in c:\users\sents\anaconda3\lib\site-packages (from lazy_loader>=0.4->arviz_base<1.4.0,>=1.3.0->arviz) (26.2)
# Requirement already satisfied: pandas>=2.1 in c:\users\sents\anaconda3\lib\site-packages (from xarray>=2024.11.0->arviz_base<1.4.0,>=1.3.0->arviz) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sents\anaconda3\lib\site-packages (from pandas>=2.1->xarray>=2024.11.0->arviz_base<1.4.0,>=1.3.0->arviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sents\anaconda3\lib\site-packages (from pandas>=2.1->xarray>=2024.11.0->arviz_base<1.4.0,>=1.3.0->arviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sents\anaconda3\lib\site-packages (from pandas>=2.1->xarray>=2024.11.0->arviz_base<1.4.0,>=1.3.0->arviz) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sents\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray>=2024.11.0->arviz_base<1.4.0,>=1.3.0->arviz) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import pymc as pm
import arviz as az

print("pymc  ", pm.__version__)
print("arviz ", az.__version__)

# ArviZ changed some function names between version 0.x and 1.x.
# This one line means the rest of the notebook works on either version.
AZ_MAJOR = int(az.__version__.split(".")[0])
plot_ppc = getattr(az, "plot_ppc", None) or az.plot_ppc_dist
# Out:
# g++ not available, if using conda: `conda install gxx`
# pymc   6.3.2
# arviz  1.3.0

# %%
conda install -c conda-forge compilers

# %%
sudo apt update
sudo apt install build-essential
